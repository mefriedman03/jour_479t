# %% [markdown]
# # Week 3: Content analysis with LLMs

# %%
import os 
import json
import ollama

# %% [markdown]
# ### First, let's load the CNS data we scraped

# %%
# load cns data 
with open('data/cns_stories.json', 'r') as filepath:
    cns_stories = json.load(filepath)

# %%
with open('data/dbk_stories.json', 'r') as dbk_filepath:
    dbk_stories = json.load(dbk_filepath)

# %% [markdown]
# ### How many stories do we have in each dataset?

# %%
# how many stories do we have in our dataset? 
print(f"Our CNS dataset contains {len(cns_stories)} stories.")
print(f"Our Diamondback dataset contains {len(dbk_stories)} stories.")
# Out:
# Our CNS dataset contains 1000 stories.
# Our Diamondback dataset contains 1000 stories.

# %%
# Let's see the structure of the json data for CNS.
print(type(cns_stories), type(cns_stories[0]))
print("CNS keys:", list(cns_stories[0].keys()))
# Out:
# <class 'list'> <class 'dict'>
# CNS keys: ['id', 'date', 'date_gmt', 'guid', 'modified', 'modified_gmt', 'slug', 'status', 'type', 'link', 'title', 'content', 'excerpt', 'author', 'featured_media', 'comment_status', 'ping_status', 'sticky', 'template', 'format', 'meta', 'categories', 'tags', 'coauthors', 'class_list', 'parsely', 'jetpack_publicize_connections', 'jetpack_featured_media_url', 'jetpack_shortlink', 'jetpack_sharing_enabled', '_links']

# %%
# same for dbk 
print("DBK keys:", list(dbk_stories[0].keys()))
# Out:
# DBK keys: ['id', 'date', 'date_gmt', 'guid', 'modified', 'modified_gmt', 'slug', 'status', 'type', 'link', 'title', 'content', 'excerpt', 'author', 'featured_media', 'comment_status', 'ping_status', 'sticky', 'template', 'format', 'meta', 'categories', 'tags', 'class_list', 'acf', 'apple_news_notices', '_links']

# %% [markdown]
# ### Let's look at a snippet of each to see how they're structured

# %%
# look at a snippet of each
print(json.dumps(cns_stories[0], indent=2))
# Out:
# {
#   "id": 126059,
#   "date": "2026-02-17T20:31:13",
#   "date_gmt": "2026-02-18T01:31:13",
#   "guid": {
#     "rendered": "https://cnsmaryland.org/?p=126059"
#   },
#   "modified": "2026-02-17T20:31:13",
#   "modified_gmt": "2026-02-18T01:31:13",
#   "slug": "the-pressure-to-perform-changes-and-challenges-in-youth-sports",
#   "status": "publish",
#   "type": "post",
#   "link": "https://cnsmaryland.org/2026/02/17/the-pressure-to-perform-changes-and-challenges-in-youth-sports/",
#   "title": {
#     "rendered": "The pressure to perform: changes and challenges in youth sports"
#   },
#   "content": {
#     "rendered": "<p><span style=\"font-weight: 400;\">COLLEGE PARK, Md. \u2013 Youth sports is changing fast.\u00a0 What was once primarily recreational has become more commercial and competitive.\u00a0 Financial investments are\u00a0 pressuring families and players to stand out earlier as collegiate and even potential professional opportunities lure young athletes.\u00a0 Coaches, athletes, parents, and sports psychologists say \u2013 maybe it\u2019s time to call a timeout.\u00a0\u00a0</span></p>\n",
#     "protected": false
#   },
#   "excerpt": {
#     "rendered": "<p>COLLEGE PARK, Md. \u2013 Youth sports is changing fast.  What was once primarily recreational has become more commercial and competitive.  Financial investments are  pressuring families and players to stand out earlier as collegiate and even potential professional opportunities lure young athletes.  Coaches, athletes, parents, and sports psychologists say \u2013 maybe it\u2019s time to call a timeout. </p>\n",
#     "protected": false
#   },
#   "author": 1703,
#   "featured_media": 126056,
#   "comment_status": "closed",
#   "ping_status": "closed",
#   "sticky": false,
#   "template": "",
#   "format": "video",
#   "meta": {
#     "advanced_seo_description": "",
#     "jetpack_seo_html_title": "",
#     "jetpack_seo_noindex": false,
#     "jetpack_post_was_ever_published": false,
#     "cybocfi_hide_featured_image": "",
#     "_jetpack_newsletter_access": "",
#     "_jetpack_dont_email_post_to_subs": false,
#     "_jetpack_newsletter_tier_id": 0,
#     "_jetpack_memberships_contains_paywalled_content": false,
#     "_jetpack_memberships_contains_paid_content": false,
#     "footnotes": "",
#     "jetpack_publicize_message": "",
#     "jetpack_publicize_feature_enabled": true,
#     "jetpack_social_post_already_shared": true,
#     "jetpack_social_options": {
#       "image_generator_settings": {
#         "template": "highway",
#         "default_image_id": 0,
#         "font": "",
#         "enabled": false
#       },
#       "version": 2
#     }
#   },
#   "categories": [
#     112,
#     114
#   ],
#   "tags": [
#     95,
#     96,
#     89,
#     97,
#     150,
#     9418,
#     260
#   ],
#   "coauthors": [
#     22661
#   ],
#   "class_list": [
#     "post-126059",
#     "post",
#     "type-post",
#     "status-publish",
#     "format-video",
#     "has-post-thumbnail",
#     "hentry",
#     "category-cns-tv",
#     "category-maryland",
#     "tag-capital-news-service",
#     "tag-cns",
#     "tag-cns-tv",
#     "tag-cnstv",
#     "tag-maryland",
#     "tag-maryland-capital-news-service",
#     "tag-sports",
#     "post_format-post-format-video"
#   ],
#   "parsely": {
#     "version": "1.1.0",
#     "canonical_url": "https://cnsmaryland.org/2026/02/17/the-pressure-to-perform-changes-and-challenges-in-youth-sports/",
#     "smart_links": {
#       "inbound": 0,
#       "outbound": 0
#     },
#     "traffic_boost_suggestions_count": 0,
#     "meta": {
#       "@context": "https://schema.org",
#       "@type": "NewsArticle",
#       "headline": "The pressure to perform: changes and challenges in youth sports",
#       "url": "http://cnsmaryland.org/2026/02/17/the-pressure-to-perform-changes-and-challenges-in-youth-sports/",
#       "mainEntityOfPage": {
#         "@type": "WebPage",
#         "@id": "http://cnsmaryland.org/2026/02/17/the-pressure-to-perform-changes-and-challenges-in-youth-sports/"
#       },
#       "thumbnailUrl": "https://cnsmaryland.org/wp-content/uploads/2026/02/Screenshot-2026-02-17-at-11.09.20-AM-1-150x150.png",
#       "image": {
#         "@type": "ImageObject",
#         "url": "https://cnsmaryland.org/wp-content/uploads/2026/02/Screenshot-2026-02-17-at-11.09.20-AM-1-scaled.png"
#       },
#       "articleSection": "CNS TV",
#       "author": [
#         {
#           "@type": "Person",
#           "name": "Benjamin Kaufman"
#         }
#       ],
#       "creator": [
#         "Benjamin Kaufman"
#       ],
#       "publisher": {
#         "@type": "Organization",
#         "name": "CNS Maryland",
#         "logo": ""
#       },
#       "keywords": [
#         "capital news service",
#         "cns",
#         "cns tv",
#         "cnstv",
#         "maryland",
#         "maryland capital news service",
#         "sports"
#       ],
#       "dateCreated": "2026-02-18T01:31:13Z",
#       "datePublished": "2026-02-18T01:31:13Z",
#       "dateModified": "2026-02-18T01:31:13Z"
#     },
#     "rendered": "<script type=\"application/ld+json\" class=\"wp-parsely-metadata\">{\"@context\":\"https:\\/\\/schema.org\",\"@type\":\"NewsArticle\",\"headline\":\"The pressure to perform: changes and challenges in youth sports\",\"url\":\"http:\\/\\/cnsmaryland.org\\/2026\\/02\\/17\\/the-pressure-to-perform-changes-and-challenges-in-youth-sports\\/\",\"mainEntityOfPage\":{\"@type\":\"WebPage\",\"@id\":\"http:\\/\\/cnsmaryland.org\\/2026\\/02\\/17\\/the-pressure-to-perform-changes-and-challenges-in-youth-sports\\/\"},\"thumbnailUrl\":\"https:\\/\\/cnsmaryland.org\\/wp-content\\/uploads\\/2026\\/02\\/Screenshot-2026-02-17-at-11.09.20-AM-1-150x150.png\",\"image\":{\"@type\":\"ImageObject\",\"url\":\"https:\\/\\/cnsmaryland.org\\/wp-content\\/uploads\\/2026\\/02\\/Screenshot-2026-02-17-at-11.09.20-AM-1-scaled.png\"},\"articleSection\":\"CNS TV\",\"author\":[{\"@type\":\"Person\",\"name\":\"Benjamin Kaufman\"}],\"creator\":[\"Benjamin Kaufman\"],\"publisher\":{\"@type\":\"Organization\",\"name\":\"CNS Maryland\",\"logo\":\"\"},\"keywords\":[\"capital news service\",\"cns\",\"cns tv\",\"cnstv\",\"maryland\",\"maryland capital news service\",\"sports\"],\"dateCreated\":\"2026-02-18T01:31:13Z\",\"datePublished\":\"2026-02-18T01:31:13Z\",\"dateModified\":\"2026-02-18T01:31:13Z\"}</script>",
#     "tracker_url": "https://cdn.parsely.com/keys/cnsmaryland.org/p.js"
#   },
#   "jetpack_publicize_connections": [],
#   "jetpack_featured_media_url": "https://cnsmaryland.org/wp-content/uploads/2026/02/Screenshot-2026-02-17-at-11.09.20-AM-1-scaled.png",
#   "jetpack_shortlink": "https://wp.me/p7Q7wK-wNd",
#   "jetpack_sharing_enabled": true,
#   "_links": {
#     "self": [
#       {
#         "href": "https://cnsmaryland.org/wp-json/wp/v2/posts/126059",
#         "targetHints": {
#           "allow": [
#             "GET"
#           ]
#         }
#       }
#     ],
#     "collection": [
#       {
#         "href": "https://cnsmaryland.org/wp-json/wp/v2/posts"
#       }
#     ],
#     "about": [
#       {
#         "href": "https://cnsmaryland.org/wp-json/wp/v2/types/post"
#       }
#     ],
#     "author": [
#       {
#         "embeddable": true,
#         "href": "https://cnsmaryland.org/wp-json/wp/v2/users/1703"
#       }
#     ],
#     "replies": [
#       {
#         "embeddable": true,
#         "href": "https://cnsmaryland.org/wp-json/wp/v2/comments?post=126059"
#       }
#     ],
#     "version-history": [
#       {
#         "count": 1,
#         "href": "https://cnsmaryland.org/wp-json/wp/v2/posts/126059/revisions"
#       }
#     ],
#     "predecessor-version": [
#       {
#         "id": 126060,
#         "href": "https://cnsmaryland.org/wp-json/wp/v2/posts/126059/revisions/126060"
#       }
#     ],
#     "wp:featuredmedia": [
#       {
#         "embeddable": true,
#         "href": "https://cnsmaryland.org/wp-json/wp/v2/media/126056"
#       }
#     ],
#     "wp:attachment": [
#       {
#         "href": "https://cnsmaryland.org/wp-json/wp/v2/media?parent=126059"
#       }
#     ],
#     "wp:term": [
#       {
#         "taxonomy": "category",
#         "embeddable": true,
#         "href": "https://cnsmaryland.org/wp-json/wp/v2/categories?post=126059"
#       },
#       {
#         "taxonomy": "post_tag",
#         "embeddable": true,
#         "href": "https://cnsmaryland.org/wp-json/wp/v2/tags?post=126059"
#       },
#       {
#         "taxonomy": "author",
#         "embeddable": true,
#         "href": "https://cnsmaryland.org/wp-json/wp/v2/coauthors?post=126059"
#       }
#     ],
#     "curies": [
#       {
#         "name": "wp",
#         "href": "https://api.w.org/{rel}",
#         "templated": true
#       }
#     ]
#   }
# }

# %%
# JSON snippet for DBK 
print(json.dumps(dbk_stories[0], indent=2))
# Out:
# {
#   "id": 478595,
#   "date": "2026-02-17T22:58:26",
#   "date_gmt": "2026-02-18T03:58:26",
#   "guid": {
#     "rendered": "https://dbknews.com/?p=478595"
#   },
#   "modified": "2026-02-17T22:58:26",
#   "modified_gmt": "2026-02-18T03:58:26",
#   "slug": "sga-accountability-umbc-alum-disappeared-philippines",
#   "status": "publish",
#   "type": "post",
#   "link": "https://dbknews.com/2026/02/17/sga-accountability-umbc-alum-disappeared-philippines/",
#   "title": {
#     "rendered": "UMD SGA calls for accountability after UMBC alum disappeared in Philippines"
#   },
#   "content": {
#     "rendered": "<p>Sacha Llanto said one of the longest weeks of his life was when his friend, Chantal Anicoche, went missing in the Philippines after a military attack.</p>\n<p>Anicoche, a University of Maryland, Baltimore County alum, was conducting humanitarian work when the Armed Forces of the Philippines conducted bombings in Abra de Ilog, Occidental Mindoro on Jan. 1, according to a petition circulated by the Action Network. Anicoche was missing for about a week before resurfacing in media reports \u2014 she was held in military custody for almost a month before returning to the U.S. at the end of January amid pressure from advocacy groups.</p>\n<p>\u201cIt was really about keeping the spirits up, about knowing that she was alive and knowing that she\u2019ll come home eventually,\u201d Llanto, a senior public health science major and a member of Filipino advocacy organization Kabataan Alliance DMV, told The Diamondback.</p>\n<p>A recently passed University of Maryland Student Government Association resolution will call for an independent investigation into the source of weapons used in the Jan. 1 Philippines attack and urges the University System of Maryland to audit holdings in companies that allegedly supplied helicopters and missiles to the Philippines\u2019 armed forces.</p>\n<p><em><strong>[<a href=\"https://dbknews.com/2026/02/12/umd-sga-university-system-maryland-divesment-resolution/\" target=\"_blank\" rel=\"noopener\">UMD SGA resolution calls on USM to divest from weapons companies</a>]</strong></em></p>\n<p>The Armed Forces of the Philippines deployed four attack helicopters and dropped at least 12 aerial bombs, which killed at least three children and two student researchers, according to the Action Network.</p>\n<p>\u201cAnicoche went to the Philippines to learn directly from the Mangyan community about their issues and aspirations, especially in the face of economic hardship and environmental degradation,\u201d the petition for Anicoche\u2019s release read.</p>\n<p>The SGA resolution passed 19-0-1 on Wednesday. It also calls for this university and the university system\u2019s Board of Regents to protect student organizations\u2019 freedom of expression and condemn the terror-tagging of human rights organizations, or labeling people as terrorists without evidence.</p>\n<p>Resolution sponsor Zyad Khan said this university, the University of Maryland, Baltimore County and the university system offered no support when Anicoche was missing in the Philippines.</p>\n<p>Khan, an SGA representative for the computer, mathematical, and natural sciences college, said the bill calls for accountability from the entire university system for the \u201cradio silence\u201d about Anicoche\u2019s disappearance. The senior computer science major said the attack is an example of how U.S.-made weapons are used to \u201cmurder and genocide innocent people.\u201d</p>\n<p>Wednesday\u2019s resolution urges this university to disassociate from any weapon systems that facilitate human rights violations in the Philippines and elsewhere in the world. This principle is tied to the <a href=\"https://dbknews.com/2026/02/12/umd-sga-university-system-maryland-divesment-resolution/\">divestment resolution</a> SGA passed last week, according to Khan.</p>\n<p>This university said in a statement to The Diamondback that resolutions voted on by SGA are student-led and reflect perspectives of voting members. The university has previously told The Diamondback that SGA resolutions have no bearing influence on the university\u2019s actions.</p>\n<p>Gabriel Pasion, vice chairperson for Anakbayan College Park and a university alum, said understanding the relationship between this university and these defense companies goes back to the importance of divesting.</p>\n<p>Now that Anicoche has been released, Pasion said local advocacy groups have been building a united front of community-led organizations. Anicoche, along with the organization she was worki ...
#     "protected": false
#   },
#   "excerpt": {
#     "rendered": "<p>Anicoche, a UMBC alum, was conducting humanitarian work when the Armed Forces of the Philippines conducted bombings in Abra de Ilog, Occidental Mindoro on Jan. 1.</p>\n",
#     "protected": false
#   },
#   "author": 609,
#   "featured_media": 478590,
#   "comment_status": "closed",
#   "ping_status": "closed",
#   "sticky": false,
#   "template": "",
#   "format": "standard",
#   "meta": {
#     "_acf_changed": false,
#     "apple_news_api_created_at": "",
#     "apple_news_api_id": "",
#     "apple_news_api_modified_at": "",
#     "apple_news_api_revision": "",
#     "apple_news_api_share_url": "",
#     "apple_news_cover_media_provider": "image",
#     "apple_news_coverimage": 0,
#     "apple_news_coverimage_caption": "",
#     "apple_news_cover_video_id": 0,
#     "apple_news_cover_video_url": "",
#     "apple_news_cover_embedwebvideo_url": "",
#     "apple_news_is_hidden": "",
#     "apple_news_is_paid": "",
#     "apple_news_is_preview": "",
#     "apple_news_is_sponsored": "",
#     "apple_news_maturity_rating": "",
#     "apple_news_metadata": "\"\"",
#     "apple_news_pullquote": "",
#     "apple_news_pullquote_position": "middle",
#     "apple_news_slug": "",
#     "apple_news_sections": [],
#     "apple_news_suppress_video_url": false,
#     "apple_news_use_image_component": false,
#     "footnotes": ""
#   },
#   "categories": [
#     10,
#     6
#   ],
#   "tags": [
#     1675,
#     20129,
#     15008,
#     2015,
#     7622,
#     9823,
#     896
#   ],
#   "class_list": [
#     "post-478595",
#     "post",
#     "type-post",
#     "status-publish",
#     "format-standard",
#     "has-post-thumbnail",
#     "hentry",
#     "category-campus",
#     "category-news",
#     "tag-divest",
#     "tag-general-dynamics",
#     "tag-kabataan-alliance",
#     "tag-lockheed-martin",
#     "tag-philippines",
#     "tag-umbc",
#     "tag-umd-sga"
#   ],
#   "acf": [],
#   "apple_news_notices": [],
#   "_links": {
#     "self": [
#       {
#         "href": "https://dbknews.com/wp-json/wp/v2/posts/478595",
#         "targetHints": {
#           "allow": [
#             "GET"
#           ]
#         }
#       }
#     ],
#     "collection": [
#       {
#         "href": "https://dbknews.com/wp-json/wp/v2/posts"
#       }
#     ],
#     "about": [
#       {
#         "href": "https://dbknews.com/wp-json/wp/v2/types/post"
#       }
#     ],
#     "author": [
#       {
#         "embeddable": true,
#         "href": "https://dbknews.com/wp-json/wp/v2/users/609"
#       }
#     ],
#     "replies": [
#       {
#         "embeddable": true,
#         "href": "https://dbknews.com/wp-json/wp/v2/comments?post=478595"
#       }
#     ],
#     "version-history": [
#       {
#         "count": 0,
#         "href": "https://dbknews.com/wp-json/wp/v2/posts/478595/revisions"
#       }
#     ],
#     "wp:featuredmedia": [
#       {
#         "embeddable": true,
#         "href": "https://dbknews.com/wp-json/wp/v2/media/478590"
#       }
#     ],
#     "wp:attachment": [
#       {
#         "href": "https://dbknews.com/wp-json/wp/v2/media?parent=478595"
#       }
#     ],
#     "wp:term": [
#       {
#         "taxonomy": "category",
#         "embeddable": true,
#         "href": "https://dbknews.com/wp-json/wp/v2/categories?post=478595"
#       },
#       {
#         "taxonomy": "post_tag",
#         "embeddable": true,
#         "href": "https://dbknews.com/wp-json/wp/v2/tags?post=478595"
#       }
#     ],
#     "curies": [
#       {
#         "name": "wp",
#         "href": "https://api.w.org/{rel}",
#         "templated": true
#       }
#     ]
#   }
# }

# %% [markdown]
# ## Now, let's use ollama to create queries.
# Let's do an example one together

# %% [markdown]
# ### Let's see if the LLM can identify the people who are quoted in a Diamondback story

# %%
# Find a DBK story by URL and ask Ollama who is quoted
MODEL = "llama3"  # change to an installed Ollama model name if needed
target_url = "https://dbknews.com/2026/02/13/umd-discovery-house-graduate-affordability/"
target_story = next((s for s in dbk_stories if s.get("link") == target_url), None)

if not target_story:
    print("Story not found in dbk_stories. Make sure dbk_stories.json includes this URL.")
else:
    title = target_story.get("title", {}).get("rendered", "")
    content = target_story.get("content", {}).get("rendered", "")
    prompt = (
        "From the story text, list EVERY person who is directly quoted. "
        "Return ONLY a python list of full names (strings). If none, return an empty array.\n\n"
        f"Title: {title}\n\nStory:\n{content}"
    )
    try:
        response = ollama.generate(model=MODEL, prompt=prompt)
        print(response["response"])
    except Exception as exc:
        print("Ollama error:", exc)
# Out:
# Here is the list of directly quoted people:
#
# `['Keegan Clements-Housser', 'Lucas Rengifo-Keller', 'Dennis Passarella-George', 'Stephen Roth', 'Jason Farman']`
#
# Note that these are full names, as requested.

# %% [markdown]
# ## What if I want to know the number of times someone is quoted OR paraphrased in that same story?

# %%
# Count direct quotes + paraphrased attributions per person in the same story
MODEL = "llama3"  # change if needed
target_url = "https://dbknews.com/2026/02/13/umd-discovery-house-graduate-affordability/"
target_story = next((s for s in dbk_stories if s.get("link") == target_url), None)

if not target_story:
    print("Story not found in dbk_stories. Make sure dbk_stories.json includes this URL.")
else:
    title = target_story.get("title", {}).get("rendered", "")
    content = target_story.get("content", {}).get("rendered", "")
    ## THIS IS THE PROMPT -- THIS IS WHAT YOU CONTROL!!!!!!!
    prompt = (
        "You are a meticulous editor. For the story below, identify EVERY person who is either (a) directly quoted, "
        "or (b) attributed via paraphrased information (e.g., 'X said', 'according to X', 'X stated').\n\n"
        "Return ONLY a JSON array. Each item must be an object with: "
        "name (full name), direct_quote_count (integer), paraphrase_count (integer), evidence (array of short snippets).\n\n"
        "If none, return an empty array.\n\n"
        f"Title: {title}\n\nStory:\n{content}"
    )
    try:
        response = ollama.generate(model=MODEL, prompt=prompt)
        print(response["response"])
    except Exception as exc:
        print("Ollama error:", exc)
# Out:
# Here is the JSON array of people mentioned in the article:
#
# ```
# [
#   {
#     "name": "Stephen Roth",
#     "direct_quote_count": 1,
#     "paraphrase_count": 2,
#     "evidence": [
#       "\"From focus groups, even before the thing was designed, helping to understand the market and the need within the community, and then throughout the process, they've been involved in the design efforts,\" ",
#       "Roth said."
#     ]
#   },
#   {
#     "name": "Keegan Clements-Housser",
#     "direct_quote_count": 2,
#     "paraphrase_count": 3,
#     "evidence": [
#       "\"We really just need somewhere that's not priced out of our stipend level,\" ",
#       "\"Because nobody can afford to live here, people don't live here\"",
#       "\"I'm not close enough to campus to walk, so I had to get an e-bike, and my e-bike was stolen, and then I had to get a car\"",
#       "Clements-Housser said."
#     ]
#   },
#   {
#     "name": "Lucas Rengifo-Keller",
#     "direct_quote_count": 1,
#     "paraphrase_count": 0,
#     "evidence": [
#       "\"I'm not close enough to campus to walk, so I had to get an e-bike, and my e-bike was stolen, and then I had to get a car\""
#     ]
#   },
#   {
#     "name": "Dennis Passarella-George",
#     "direct_quote_count": 1,
#     "paraphrase_count": 2,
#     "evidence": [
#       "Passarella-George told The Diamondback that the university considered affordability when developing Discovery House through a public-private partnership.",
#       "All fees and utilities are included in rent, offering students 'complete transparency' and 'the ability to have a predictable monthly budget,' Passarella-George added."
#     ]
#   },
#   {
#     "name": "Jason Farman",
#     "direct_quote_count": 1,
#     "paraphrase_count": 0,
#     "evidence": [
#       "\"We're hoping that [what] the Grand Challenges Graduate Communities does is connect people with others who care about the things that they care about, who want to make a difference with the kind of research they're doing\""
#     ]
#   }
# ]
# ```
#
# Note: There are no other individuals mentioned in the article who are directly quoted or attributed via paraphrased information.

# %% [markdown]
# ### What if I want titles?

# %%
# Count direct quotes + paraphrased attributions per person in the same story
target_url = "https://dbknews.com/2026/02/17/sga-accountability-umbc-alum-disappeared-philippines/"
target_story = next((s for s in dbk_stories if s.get("link") == target_url), None)

if not target_story:
    print("Story not found in dbk_stories. Make sure dbk_stories.json includes this URL.")
else:
    title = target_story.get("title", {}).get("rendered", "")
    content = target_story.get("content", {}).get("rendered", "")
    ## THIS IS THE PROMPT -- THIS IS WHAT YOU CONTROL!!!!!!!
    prompt = (
        "For the story below, identify every person who is either (a) directly quoted, or (b) attributed via paraphrased information (e.g., 'X said', 'according to X', 'X stated').\n\n"
        "Return ONLY a JSON array with their full name, direct quote count, paraphrase count, and their title or position.\n\n"
        "If the person is a student, return their class year and major instead of title/position. If the person is a university official, return their department or office.\n\n"
        "If none, return an empty array.\n\n"
        f"Title: {title}\n\nStory:\n{content}"
    )
    try:
        response = ollama.generate(model=MODEL, prompt=prompt)
        print(response["response"])
    except Exception as exc:
        print("Ollama error:", exc)
# Out:
# Here is the JSON array with the requested information:
#
# ```
# [
#   {
#     "full_name": "Sacha Llanto",
#     "direct_quote_count": 3,
#     "paraphrase_count": 2,
#     "title_position": "Senior Public Health Science Major, Member of Filipino Advocacy Organization"
#   },
#   {
#     "full_name": "Zyad Khan",
#     "direct_quote_count": 2,
#     "paraphrase_count": 1,
#     "title_position": "SGA Representative for Computer, Mathematical, and Natural Sciences College, Senior Computer Science Major"
#   },
#   {
#     "full_name": "Gabriel Pasion",
#     "direct_quote_count": 2,
#     "paraphrase_count": 1,
#     "title_position": "Vice Chairperson for Anakbayan College Park, University Alum"
#   }
# ]
# ```
#
# Let me know if you have any further questions!

# %% [markdown]
# ### Now, what if I want to know who was quoted in the last 20 Diamondback stories as well as the number of times they were quoted?

# %%
# Per-story JSON + aggregated JSON across the last 10 DBK stories
import re
MODEL = "llama3"  # change if needed
last_10 = dbk_stories[:10]

def strip_html(html):
    if not html:
        return ""
    text = re.sub(r"<[^>]+>", " ", html)
    return re.sub(r"\s+", " ", text).strip()

def extract_json(text):
    text = text.strip()
    if not text:
        return None
    # Try direct parse first
    try:
        return json.loads(text)
    except json.JSONDecodeError:
        pass
    # Try to extract first JSON array or object
    match = re.search(r"(\[.*\]|\{.*\})", text, re.DOTALL)
    if match:
        try:
            return json.loads(match.group(1))
        except json.JSONDecodeError:
            return None
    return None

def people_mentions_for_story(story):
    title = strip_html(story.get("title", {}).get("rendered", ""))
    content = strip_html(story.get("content", {}).get("rendered", ""))
    prompt = (
        "You are a meticulous editor. For the story below, identify EVERY person who is either (a) directly quoted, "
        "or (b) attributed via paraphrased information (e.g., 'X said', 'according to X', 'X stated').\n\n"
        "EXCLUDE reporters, staff writers, editors, or byline authors. Do NOT include staff writers.\n\n"
        "Return ONLY valid JSON (no extra text). The JSON must be an array. Each item must be an object with: "
        "name (full name), direct_quote_count (integer), paraphrase_count (integer).\n\n"
        "If none, return an empty array [].\n\n"
        f"Title: {title}\n\nStory:\n{content}"
    )
    response = ollama.generate(model=MODEL, prompt=prompt)
    parsed = extract_json(response["response"])
    if parsed is None:
        print("Non-JSON response:", response["response"][:500])
        return []
    return parsed if isinstance(parsed, list) else []

per_story = []
counts = {}
for i, story in enumerate(last_10, start=1):
    try:
        people = people_mentions_for_story(story)
    except Exception as exc:
        print("Ollama error:", exc)
        continue
    per_story.append({"story_index": i, "link": story.get("link"), "people": people})
    for person in people:
        name = person.get("name") if isinstance(person, dict) else None
        if not name:
            continue
        if name not in counts:
            counts[name] = {"direct_quote_count": 0, "paraphrase_count": 0}
        counts[name]["direct_quote_count"] += int(person.get("direct_quote_count", 0))
        counts[name]["paraphrase_count"] += int(person.get("paraphrase_count", 0))

aggregated = [
    {
        "name": name,
        "direct_quote_count": vals["direct_quote_count"],
        "paraphrase_count": vals["paraphrase_count"],
        "total": vals["direct_quote_count"] + vals["paraphrase_count"],
    }
    for name, vals in counts.items()
 ]
aggregated.sort(key=lambda x: x["total"], reverse=True)

print(json.dumps({"per_story": per_story, "aggregated": aggregated}, indent=2))
# Out:
# {
#   "per_story": [
#     {
#       "story_index": 1,
#       "link": "https://dbknews.com/2026/02/17/sga-accountability-umbc-alum-disappeared-philippines/",
#       "people": [
#         {
#           "name": "Sacha Llanto",
#           "direct_quote_count": 2,
#           "paraphrase_count": 1
#         },
#         {
#           "name": "Zyad Khan",
#           "direct_quote_count": 3,
#           "paraphrase_count": 2
#         },
#         {
#           "name": "Gabriel Pasion",
#           "direct_quote_count": 2,
#           "paraphrase_count": 1
#         }
#       ]
#     },
#     {
#       "story_index": 2,
#       "link": "https://dbknews.com/2026/02/17/maryland-softball-lauren-karn-transfer-portal/",
#       "people": [
#         {
#           "name": "Lauren Karn",
#           "direct_quote_count": 2,
#           "paraphrase_count": 3
#         },
#         {
#           "name": "Caroline Fox",
#           "direct_quote_count": 0,
#           "paraphrase_count": 1
#         },
#         {
#           "name": "Anna McGowan",
#           "direct_quote_count": 0,
#           "paraphrase_count": 1
#         },
#         {
#           "name": "Lauren Caye",
#           "direct_quote_count": 0,
#           "paraphrase_count": 1
#         },
#         {
#           "name": "Caitlin Olensky",
#           "direct_quote_count": 0,
#           "paraphrase_count": 1
#         }
#       ]
#     },
#     {
#       "story_index": 3,
#       "link": "https://dbknews.com/2026/02/17/umd-25-demands-dashboard-black-students/",
#       "people": [
#         {
#           "name": "Georgina Dodge",
#           "direct_quote_count": 0,
#           "paraphrase_count": 1
#         },
#         {
#           "name": "Darryll Pines",
#           "direct_quote_count": 2,
#           "paraphrase_count": 1
#         }
#       ]
#     },
#     {
#       "story_index": 4,
#       "link": "https://dbknews.com/2026/02/17/umd-al-hikmah-detained-cair/",
#       "people": [
#         {
#           "name": "John Fossum",
#           "direct_quote_count": 2,
#           "paraphrase_count": 1
#         },
#         {
#           "name": "Zainab Chaudry",
#           "direct_quote_count": 0,
#           "paraphrase_count": 1
#         },
#         {
#           "name": "Riona Sheikh",
#           "direct_quote_count": 0,
#           "paraphrase_count": 1
#         }
#       ]
#     },
#     {
#       "story_index": 5,
#       "link": "https://dbknews.com/2026/02/17/maryland-football-clint-trickett-offensive-coordinator/",
#       "people": [
#         {
#           "name": "Clint Trickett",
#           "direct_quote_count": 0,
#           "paraphrase_count": 4
#         },
#         {
#           "name": "Pep Hamilton",
#           "direct_quote_count": 0,
#           "paraphrase_count": 1
#         },
#         {
#           "name": "Malik Washington",
#           "direct_quote_count": 0,
#           "paraphrase_count": 1
#         }
#       ]
#     },
#     {
#       "story_index": 6,
#       "link": "https://dbknews.com/2026/02/17/wes-moore-bans-ice-partnerships-maryland/",
#       "people": [
#         {
#           "name": "Wes Moore",
#           "direct_quote_count": 0,
#           "paraphrase_count": 1
#         },
#         {
#           "name": "Nicole Williams",
#           "direct_quote_count": 1,
#           "paraphrase_count": 1
#         }
#       ]
#     },
#     {
#       "story_index": 7,
#       "link": "https://dbknews.com/2026/02/17/how-buzz-williams-meticulous-pregame-routine-impacts-maryland-mens-basketball/",
#       "people": [
#         {
#           "name": "Steve Pikiell",
#           "direct_quote_count": 1,
#           "paraphrase_count": 0
#         },
#         {
#           "name": "Buzz Williams",
#           "direct_quote_count": 7,
#           "paraphrase_count": 4
#         },
#         {
#           "name": "Darius Adams",
#           "direct_quote_count": 0,
#           "paraphrase_count": 1
#         },
#         {
#           "name": "Andre Mills",
#           "direct_quote_count": 0,
#           "paraphrase_count": 1
#         },
#         {
#           "name": "Diggy Coit",
#           "direct_quote_count": 0,
#           "paraphrase_count": 1
#         },
#         {
#           "name": "John Calipari",
#           "direct_quote_count": 1,
#           "paraphrase_count": 0
#         },
#         {
#           "name": "Mark Pope",
#           "direct_quote_count": 1,
#           "paraphrase_count": 0
#         },
#         {
#           "name": "Trent Noah",
#           "direct_quote_count": 1,
#           "paraphrase_count": 0
#         },
#         {
#           "name": "John Wooden",
#           "direct_quote_count": 1,
#           "paraphrase_count": 0
#         },
#         {
#           "name": "Solomon Washington",
#           "direct_quote_count": 0,
#           "paraphrase_count": 2
#         },
#         {
#           "name": "Collin Metcalf",
#           "direct_quote_count": 1,
#           "paraphrase_count": 0
#         }
#       ]
#     },
#     {
#       "story_index": 8,
#       "link": "https://dbknews.com/2026/02/17/maryland-womens-basketball-ohio-state-comeback/",
#       "people": [
#         {
#           "name": "Isimenme Ozzy-Momodu",
#           "direct_quote_count": 0,
#           "paraphrase_count": 1
#         },
#         {
#           "name": "Brenda Frese",
#           "direct_quote_count": 2,
#           "paraphrase_count": 3
#         },
#         {
#           "name": "Addi Mack",
#           "direct_quote_count": 1,
#           "paraphrase_count": 0
#         },
#         {
#           "name": "Yarden Garzon",
#           "direct_quote_count": 1,
#           "paraphrase_count": 2
#         },
#         {
#           "name": "Oluchi Okananwa",
#           "direct_quote_count": 0,
#           "paraphrase_count": 1
#         },
#         {
#           "name": "Mir McLean",
#           "direct_quote_count": 0,
#           "paraphrase_count": 1
#         }
#       ]
#     },
#     {
#       "story_index": 9,
#       "link": "https://dbknews.com/2026/02/17/higher-education-maryland-general-assembly/",
#       "people": [
#         {
#           "name": "Del. Joe Vogel",
#           "direct_quote_count": 3,
#           "paraphrase_count": 2
#         },
#         {
#           "name": "Del. Mary Lehman",
#           "direct_quote_count": 3,
#           "paraphrase_count": 1
#         },
#         {
#           "name": "Del. Ashanti Martinez",
#           "direct_quote_count": 2,
#           "paraphrase_count": 1
#         }
#       ]
#     },
#     {
#       "story_index": 10,
#       "link": "https://dbknews.com/2026/02/16/umd-dining-services-muslim-student-association-prepare-accommodations-for-month-of-ramadan/",
#       "people": [
#         {
#           "name": "Rayn Ali",
#           "direct_quote_count": 2,
#           "paraphrase_count": 1
#         }
#       ]
#     }
#   ],
#   "aggregated": [
#     {
#       "name": "Buzz Williams",
#       "direct_quote_count": 7,
#       "paraphrase_count": 4,
#       "total": 11
#     },
#     {
#       "name": "Zyad Khan",
#       "direct_quote_count": 3,
#       "paraphrase_count": 2,
#       "total": 5
#     },
#     {
#       "name": "Lauren Karn",
#       "direct_quote_count": 2,
#       "paraphrase_count": 3,
#       "total": 5
#     },
#     {
#       "name": "Brenda Frese",
#       "direct_quote_count": 2,
#       "paraphrase_count": 3,
#       "total": 5
#     },
#     {
#       "name": "Del. Joe Vogel",
#       "direct_quote_count": 3,
#       "paraphrase_count": 2,
#       "total": 5
#     },
#     {
#       "name": "Clint Trickett",
#       "direct_quote_count": 0,
#       "paraphrase_count": 4,
#       "total": 4
#     },
#     {
#       "name": "Del. Mary Lehman",
#       "direct_quote_count": 3,
#       "paraphrase_count": 1,
#       "total": 4
#     },
#     {
#       "name": "Sacha Llanto",
#       "direct_quote_count": 2,
#       "paraphrase_count": 1,
#       "total": 3
#     },
#     {
#       "name": "Gabriel Pasion",
#       "direct_quote_count": 2,
#       "paraphrase_count": 1,
#       "total": 3
#     },
#     {
#       "name": "Darryll Pines",
#       "direct_quote_count": 2,
#       "paraphrase_count": 1,
#       "total": 3
#     },
#     {
#       "name": "John Fossum",
#       "direct_quote_count": 2,
#       "paraphrase_count": 1,
#       "total": 3
#     },
#     {
#       "name": "Yarden Garzon",
#       "direct_quote_count": 1,
#       "paraphrase_count": 2,
#       "total": 3
#     },
#     {
#       "name": "Del. Ashanti Martinez",
#       "direct_quote_count": 2,
#       "paraphrase_count": 1,
#       "total": 3
#     },
#     {
#       "name": "Rayn Ali",
#       "direct_quote_count": 2,
#       "paraphrase_count": 1,
#       "total": 3
#     },
#     {
#       "name": "Nicole Williams",
#       "direct_quote_count": 1,
#       "paraphrase_count": 1,
#       "total": 2
#     },
#     {
#       "name": "Solomon Washington",
#       "direct_quote_count": 0,
#       "paraphrase_count": 2,
#       "total": 2
#     },
#     {
#       "name": "Caroline Fox",
#       "direct_quote_count": 0,
#       "paraphrase_count": 1,
#       "total": 1
#     },
#     {
#       "name": "Anna McGowan",
#       "direct_quote_count": 0,
#       "paraphrase_count": 1,
#       "total": 1
#     },
#     {
#       "name": "Lauren Caye",
#       "direct_quote_count": 0,
#       "paraphrase_count": 1,
#       "total": 1
#     },
#     {
#       "name": "Caitlin Olensky",
#       "direct_quote_count": 0,
#       "paraphrase_count": 1,
#       "total": 1
#     },
#     {
#       "name": "Georgina Dodge",
#       "direct_quote_count": 0,
#       "paraphrase_count": 1,
#       "total": 1
#     },
#     {
#       "name": "Zainab Chaudry",
#       "direct_quote_count": 0,
#       "paraphrase_count": 1,
#       "total": 1
#     },
#     {
#       "name": "Riona Sheikh",
#       "direct_quote_count": 0,
#       "paraphrase_count": 1,
#       "total": 1
#     },
#     {
#       "name": "Pep Hamilton",
#       "direct_quote_count": 0,
#       "paraphrase_count": 1,
#       "total": 1
#     },
#     {
#       "name": "Malik Washington",
#       "direct_quote_count": 0,
#       "paraphrase_count": 1,
#       "total": 1
#     },
#     {
#       "name": "Wes Moore",
#       "direct_quote_count": 0,
#       "paraphrase_count": 1,
#       "total": 1
#     },
#     {
#       "name": "Steve Pikiell",
#       "direct_quote_count": 1,
#       "paraphrase_count": 0,
#       "total": 1
#     },
#     {
#       "name": "Darius Adams",
#       "direct_quote_count": 0,
#       "paraphrase_count": 1,
#       "total": 1
#     },
#     {
#       "name": "Andre Mills",
#       "direct_quote_count": 0,
#       "paraphrase_count": 1,
#       "total": 1
#     },
#     {
#       "name": "Diggy Coit",
#       "direct_quote_count": 0,
#       "paraphrase_count": 1,
#       "total": 1
#     },
#     {
#       "name": "John Calipari",
#       "direct_quote_count": 1,
#       "paraphrase_count": 0,
#       "total": 1
#     },
#     {
#       "name": "Mark Pope",
#       "direct_quote_count": 1,
#       "paraphrase_count": 0,
#       "total": 1
#     },
#     {
#       "name": "Trent Noah",
#       "direct_quote_count": 1,
#       "paraphrase_count": 0,
#       "total": 1
#     },
#     {
#       "name": "John Wooden",
#       "direct_quote_count": 1,
#       "paraphrase_count": 0,
#       "total": 1
#     },
#     {
#       "name": "Collin Metcalf",
#       "direct_quote_count": 1,
#       "paraphrase_count": 0,
#       "total": 1
#     },
#     {
#       "name": "Isimenme Ozzy-Momodu",
#       "direct_quote_count": 0,
#       "paraphrase_count": 1,
#       "total": 1
#     },
#     {
#       "name": "Addi Mack",
#       "direct_quote_count": 1,
#       "paraphrase_count": 0,
#       "total": 1
#     },
#     {
#       "name": "Oluchi Okananwa",
#       "direct_quote_count": 0,
#       "paraphrase_count": 1,
#       "total": 1
#     },
#     {
#       "name": "Mir McLean",
#       "direct_quote_count": 0,
#       "paraphrase_count": 1,
#       "total": 1
#     }
#   ]
# }

# %%
# Try generating something on your own!!!!
