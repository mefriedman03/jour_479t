# %% [markdown]
# # Week 4 - Databases

# %% [markdown]
# This week, we'll move beyond typical spreadsheets to some of the more complex ways to store data and start to create data warehouses.

# %%
# this tells us to import the libary we'll be using: peewee.
# the asterisk tells python to import everythinggggg from the library
from peewee import *

# this connects to a specific database file called example.db and creates example.db if it doesn't exist. 
db = SqliteDatabase('example.db')

class BaseModel(Model):
    class Meta:
        database = db

# %% [markdown]
# ## Relational databases

# %% [markdown]
# ## Turning spreadsheets into a database

# %% [markdown]
# Let's say I have

# %% [markdown]
# ### Optional: Using docker
